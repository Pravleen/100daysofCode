# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
names=["Preg","Plas","Pres","Skin","Test","Mass","Pedi","Age","Class"]
df=pd.read_csv('Book2.csv',names=names)

# %%
df.head()
# Out:
#    Preg  Plas  Pres  Skin  Test  Mass   Pedi  Age  Class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    70    80    15     0  26.6  0.351   31      0
# 2     8   198    50    45     0  23.3  0.191   41      1
# 3     1    11    55    19     0  28.1  0.545   29      0
# 4    11   120    85    25    45  43.3  0.365   25      1

# %%
df.shape
# Out:
# (25, 9)

# %%
df.describe()
# Out:
#             Preg        Plas        Pres      Skin       Test        Mass  \
# count  25.000000   25.000000   25.000000  25.00000  25.000000   25.000000
# mean    4.720000  131.560000   60.320000  25.92000  17.760000   52.364000
# std     3.421988   44.722366   29.437391  12.51306  27.887094  104.167765
# min     0.000000   11.000000    0.000000   0.00000   0.000000    0.000000
# 25%     1.000000  111.000000   50.000000  18.00000   0.000000   23.500000
# 50%     5.000000  133.000000   66.000000  26.00000   0.000000   33.400000
# 75%     8.000000  157.000000   83.000000  35.00000  29.000000   38.100000
# max    11.000000  200.000000  100.000000  47.00000  97.000000  543.000000
#
#              Pedi        Age      Class
# count   25.000000  25.000000  25.000000
# mean     5.756200  35.520000   0.560000
# std     27.135174  12.711937   0.506623
# min      0.000000  21.000000   0.000000
# 25%      0.191000  25.000000   0.000000
# 50%      0.265000  31.000000   1.000000
# 75%      0.485000  43.000000   1.000000
# max    136.000000  65.000000   1.000000

# %%
corr=df.corr()

# %%
corr[corr>0.5]
# Out:
#        Preg  Plas  Pres      Skin      Test  Mass      Pedi       Age  Class
# Preg    1.0   NaN   NaN       NaN       NaN   NaN       NaN       NaN    NaN
# Plas    NaN   1.0   NaN       NaN       NaN   NaN       NaN       NaN    NaN
# Pres    NaN   NaN   1.0       NaN       NaN   NaN       NaN       NaN    NaN
# Skin    NaN   NaN   NaN  1.000000       NaN   NaN       NaN  0.569221    NaN
# Test    NaN   NaN   NaN       NaN  1.000000   NaN  0.593973       NaN    NaN
# Mass    NaN   NaN   NaN       NaN       NaN   1.0       NaN       NaN    NaN
# Pedi    NaN   NaN   NaN       NaN  0.593973   NaN  1.000000       NaN    NaN
# Age     NaN   NaN   NaN  0.569221       NaN   NaN       NaN  1.000000    NaN
# Class   NaN   NaN   NaN       NaN       NaN   NaN       NaN       NaN    1.0

# %%
df.skew()
# Out:
# Preg     0.232400
# Plas    -0.606237
# Pres    -0.846947
# Skin    -0.272123
# Test     1.533213
# Mass     4.705661
# Pedi     4.999370
# Age      0.979220
# Class   -0.257459
# dtype: float64

# %%
df.groupby('Age').size()
# Out:
# Age
# 21    1
# 22    1
# 23    1
# 24    2
# 25    2
# 29    3
# 30    1
# 31    3
# 32    1
# 33    1
# 34    1
# 41    1
# 43    1
# 50    2
# 52    1
# 53    1
# 61    1
# 65    1
# dtype: int64

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df,figsize=(10,7));

# %%
df.hist(figsize=(10,7));

# %%
df.plot(kind='line', subplots=True ,layout=(3,3),figsize=(10,7));

# %%
df['Test'].plot(kind='line', subplots=True ,layout=(3,3),figsize=(10,7));

# %%
df.plot(kind='box', subplots=True ,layout=(3,3),figsize=(10,7));

# %%
import seaborn as sns

# %%
sns.heatmap(corr)

# %%
sns.barplot('Class','Preg',data=df)

# %%
df[df['Class']==0]['Preg'].mean( )
# Out:
# 4.636363636363637
