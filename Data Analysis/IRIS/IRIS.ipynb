# %%
#import dependencies
import pandas as pd
from matplotlib import pylab
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("iris.data",header=None)

# %%
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
headers=["Sepel_length","Sepal_width","Petal_length","Petal_width","Class"]
df.columns=headers

# %%
df.head()
# Out:
#    Sepel_length  Sepal_width  Petal_length  Petal_width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.dtypes
# Out:
# Sepel_length    float64
# Sepal_width     float64
# Petal_length    float64
# Petal_width     float64
# Class            object
# dtype: object

# %%
df.columns
# Out:
# Index(['Sepel_length', 'Sepal_width', 'Petal_length', 'Petal_width', 'Class'], dtype='object')

# %%
df.describe()
# Out:
#        Sepel_length  Sepal_width  Petal_length  Petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.describe(include="all")
# Out:
#         Sepel_length  Sepal_width  Petal_length  Petal_width           Class
# count     150.000000   150.000000    150.000000   150.000000             150
# unique           NaN          NaN           NaN          NaN               3
# top              NaN          NaN           NaN          NaN  Iris-virginica
# freq             NaN          NaN           NaN          NaN              50
# mean        5.843333     3.054000      3.758667     1.198667             NaN
# std         0.828066     0.433594      1.764420     0.763161             NaN
# min         4.300000     2.000000      1.000000     0.100000             NaN
# 25%         5.100000     2.800000      1.600000     0.300000             NaN
# 50%         5.800000     3.000000      4.350000     1.300000             NaN
# 75%         6.400000     3.300000      5.100000     1.800000             NaN
# max         7.900000     4.400000      6.900000     2.500000             NaN

# %%
df[["Sepel_length","Petal_length"]].describe()
# Out:
#        Sepel_length  Petal_length
# count    150.000000    150.000000
# mean       5.843333      3.758667
# std        0.828066      1.764420
# min        4.300000      1.000000
# 25%        5.100000      1.600000
# 50%        5.800000      4.350000
# 75%        6.400000      5.100000
# max        7.900000      6.900000

# %%
df.info
# Out:
# <bound method DataFrame.info of      Sepel_length  Sepal_width  Petal_length  Petal_width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
df["Sepel_length+new"]=df["Sepel_length"]/df["Sepel_length"].max()

# %%
df.head()
# Out:
#    Sepel_length  Sepal_width  Petal_length  Petal_width        Class  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    Sepel_length+new
# 0          0.645570
# 1          0.620253
# 2          0.594937
# 3          0.582278
# 4          0.632911

# %%
plt.hist(df["Sepel_length"])
plt.xlabel("Sepel length")
plt.ylabel("Count")
plt.title("Sepal length histogram")
plt.show()

# %%
bins=np.linspace(df["Sepel_length"].min(),df["Sepel_length"].max(),4)
group_name=["Small","Medium","Large"]

# %%
df["Sepel_length_binned"]=pd.cut(df["Sepel_length"],bins,labels=group_name,include_lowest=True)

# %%
df[["Sepel_length","Sepel_length_binned"]]
# Out:
#      Sepel_length Sepel_length_binned
# 0             5.1               Small
# 1             4.9               Small
# 2             4.7               Small
# 3             4.6               Small
# 4             5.0               Small
# ..            ...                 ...
# 145           6.7              Medium
# 146           6.3              Medium
# 147           6.5              Medium
# 148           6.2              Medium
# 149           5.9              Medium
#
# [150 rows x 2 columns]

# %%
df["Sepel_length_binned"].value_counts()
# Out:
# Medium    71
# Small     59
# Large     20
# Name: Sepel_length_binned, dtype: int64

# %%
plt.hist(df["Sepel_length_binned"],color="red",bins=3)
plt.xlabel("Sepel length")
plt.ylabel("Count")
plt.title("Sepal length binned histogram")
plt.show()

# %%
dummy_variable_1=pd.get_dummies(df["Class"])
dummy_variable_1.head()
# Out:
#    Iris-setosa  Iris-versicolor  Iris-virginica
# 0            1                0               0
# 1            1                0               0
# 2            1                0               0
# 3            1                0               0
# 4            1                0               0

# %%
df=pd.concat([df,dummy_variable_1],axis=1)

# %%
df
# Out:
#      Sepel_length  Sepal_width  Petal_length  Petal_width           Class  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      Sepel_length+new Sepel_length_binned  Iris-setosa  Iris-versicolor  \
# ...

# %%
df.corr()
# Out:
#                   Sepel_length  Sepal_width  Petal_length  Petal_width  \
# Sepel_length          1.000000    -0.109369      0.871754     0.817954
# Sepal_width          -0.109369     1.000000     -0.420516    -0.356544
# Petal_length          0.871754    -0.420516      1.000000     0.962757
# Petal_width           0.817954    -0.356544      0.962757     1.000000
# Sepel_length+new      1.000000    -0.109369      0.871754     0.817954
# Iris-setosa          -0.717416     0.595601     -0.922688    -0.887510
# Iris-versicolor       0.079396    -0.464700      0.201587     0.118376
# Iris-virginica        0.638020    -0.130901      0.721102     0.769134
#
#                   Sepel_length+new  Iris-setosa  Iris-versicolor  \
# Sepel_length              1.000000    -0.717416         0.079396
# Sepal_width              -0.109369     0.595601        -0.464700
# Petal_length              0.871754    -0.922688         0.201587
# Petal_width               0.817954    -0.887510         0.118376
# ...

# %%
sns.regplot(x="Sepel_length",y="Petal_length",data=df)
plt.ylim(0,)
# Out:
# (0, 8.625354235105384)

# %%
df[["Sepel_length","Petal_length"]].corr()
# Out:
#               Sepel_length  Petal_length
# Sepel_length      1.000000      0.871754
# Petal_length      0.871754      1.000000

# %%
sns.regplot(x="Sepel_length",y="Sepal_width",data=df)
plt.ylim(0,)
# Out:
# (0, 4.525098427152319)

# %%
df[["Sepel_length","Sepal_width"]].corr()
# Out:
#               Sepel_length  Sepal_width
# Sepel_length      1.000000    -0.109369
# Sepal_width      -0.109369     1.000000

# %%
sns.regplot(x="Sepal_width",y="Iris-setosa",data=df)
plt.ylim(0,)
# Out:
# (0, 1.6053789468411308)

# %%
sns.regplot(x="Sepal_width",y="Iris-versicolor",data=df)
plt.ylim(0,)
# Out:
# (0, 1.1968457829734953)

# %%
sns.regplot(x="Sepal_width",y="Iris-virginica",data=df)
plt.ylim(0,)
# Out:
# (0, 1.055364179738999)

# %% [markdown]
# So larger the sepal-width most likely it is to iris-setosa

# %%
sns.regplot(x="Sepel_length",y="Iris-virginica",data=df)
plt.ylim(0,)
# Out:
# (0, 1.3852575645089868)

# %%
sns.regplot(x="Sepel_length",y="Iris-versicolor",data=df)
plt.ylim(0,)
# Out:
# (0, 1.0505564753495218)

# %%
sns.regplot(x="Sepel_length",y="Iris-setosa",data=df)
plt.ylim(0,)
# Out:
# (0, 1.269193744519427)

# %% [markdown]
# So sepal length is directly proportional to Iris-virginica

# %%
sns.boxplot(x="Sepel_length_binned",y="Sepal_width",data=df)

# %%
df.describe()
# Out:
#        Sepel_length  Sepal_width  Petal_length  Petal_width  Sepel_length+new  \
# count    150.000000   150.000000    150.000000   150.000000        150.000000
# mean       5.843333     3.054000      3.758667     1.198667          0.739662
# std        0.828066     0.433594      1.764420     0.763161          0.104818
# min        4.300000     2.000000      1.000000     0.100000          0.544304
# 25%        5.100000     2.800000      1.600000     0.300000          0.645570
# 50%        5.800000     3.000000      4.350000     1.300000          0.734177
# 75%        6.400000     3.300000      5.100000     1.800000          0.810127
# max        7.900000     4.400000      6.900000     2.500000          1.000000
#
#        Iris-setosa  Iris-versicolor  Iris-virginica
# count   150.000000       150.000000      150.000000
# mean      0.333333         0.333333        0.333333
# std       0.472984         0.472984        0.472984
# min       0.000000         0.000000        0.000000
# ...

# %%
df.describe(include='all')
# Out:
#         Sepel_length  Sepal_width  Petal_length  Petal_width           Class  \
# count     150.000000   150.000000    150.000000   150.000000             150
# unique           NaN          NaN           NaN          NaN               3
# top              NaN          NaN           NaN          NaN  Iris-virginica
# freq             NaN          NaN           NaN          NaN              50
# mean        5.843333     3.054000      3.758667     1.198667             NaN
# std         0.828066     0.433594      1.764420     0.763161             NaN
# min         4.300000     2.000000      1.000000     0.100000             NaN
# 25%         5.100000     2.800000      1.600000     0.300000             NaN
# 50%         5.800000     3.000000      4.350000     1.300000             NaN
# 75%         6.400000     3.300000      5.100000     1.800000             NaN
# max         7.900000     4.400000      6.900000     2.500000             NaN
#
# ...

# %%
df["Sepel_length"].value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 5.5     7
# 5.8     7
# 6.4     7
# 6.0     6
# 4.9     6
# 6.1     6
# 5.4     6
# 5.6     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 5.2     4
# 6.2     4
# 4.6     4
# 7.2     3
# 6.8     3
# 4.4     3
# 5.9     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 4.3     1
# 7.9     1
# 7.3     1
# 7.0     1
# 4.5     1
# 5.3     1
# 7.1     1
# Name: Sepel_length, dtype: int64

# %%
df["Sepel_length"].value_counts().to_frame()
# Out:
#      Sepel_length
# 5.0            10
# 6.3             9
# 5.1             9
# 6.7             8
# 5.7             8
# 5.5             7
# 5.8             7
# 6.4             7
# 6.0             6
# 4.9             6
# 6.1             6
# 5.4             6
# 5.6             6
# 6.5             5
# 4.8             5
# 7.7             4
# 6.9             4
# 5.2             4
# 6.2             4
# 4.6             4
# 7.2             3
# 6.8             3
# 4.4             3
# 5.9             3
# 6.6             2
# 4.7             2
# 7.6             1
# 7.4             1
# 4.3             1
# 7.9             1
# 7.3             1
# 7.0             1
# 4.5             1
# 5.3             1
# 7.1             1

# %%
df["Sepal_width"].value_counts().to_frame()
# Out:
#      Sepal_width
# 3.0           26
# 2.8           14
# 3.2           13
# 3.4           12
# 3.1           12
# 2.9           10
# 2.7            9
# 2.5            8
# 3.5            6
# 3.8            6
# 3.3            6
# 2.6            5
# 2.3            4
# 3.6            3
# 2.4            3
# 2.2            3
# 3.7            3
# 3.9            2
# 4.2            1
# 4.1            1
# 4.4            1
# 2.0            1
# 4.0            1

# %%
df['Class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df_group=df[['Sepel_length','Sepal_width','Petal_width']]

# %%
df_group=df_group.groupby(['Sepel_length','Sepal_width'],as_index=False).mean()

# %%
df_group
# Out:
#      Sepel_length  Sepal_width  Petal_width
# 0             4.3          3.0          0.1
# 1             4.4          2.9          0.2
# 2             4.4          3.0          0.2
# 3             4.4          3.2          0.2
# 4             4.5          2.3          0.3
# ..            ...          ...          ...
# 111           7.7          2.6          2.3
# 112           7.7          2.8          2.0
# 113           7.7          3.0          2.3
# 114           7.7          3.8          2.2
# 115           7.9          3.8          2.0
#
# [116 rows x 3 columns]
