# %% [markdown]
# # CARS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df=pd.read_csv("cars.csv")

# %%
df
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    14.0           8          350  165       4209           12   1972
# 1    31.9           4           89   71       1925           14   1980
# 2    17.0           8          302  140       3449           11   1971
# 3    15.0           8          400  150       3761           10   1971
# 4    30.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  17.0           8          305  130       3840           15   1980
# 257  36.1           4           91   60       1800           16   1979
# 258  22.0           6          232  112       2835           15   1983
# 259  18.0           6          232  100       3288           16   1972
# 260  22.0           6          250  105       3353           15   1977
#
#         brand
# 0         US.
# 1     Europe.
# 2         US.
# 3         US.
# 4         US.
# ..        ...
# ...

# %%
df.describe(include="all") #If we want to see descropetion of every column
# Out:
#                mpg   cylinders  cubicinches          hp  weightlbs  \
# count   261.000000  261.000000          261  261.000000        261
# unique         NaN         NaN           75         NaN        241
# top            NaN         NaN           97         NaN       2130
# freq           NaN         NaN           16         NaN          3
# mean     23.144828    5.590038          NaN  106.360153        NaN
# std       7.823570    1.733310          NaN   40.499959        NaN
# min      10.000000    3.000000          NaN   46.000000        NaN
# 25%      16.900000    4.000000          NaN   75.000000        NaN
# 50%      22.000000    6.000000          NaN   95.000000        NaN
# 75%      28.800000    8.000000          NaN  138.000000        NaN
# max      46.600000    8.000000          NaN  230.000000        NaN
#
#          time-to-60         year  brand
# count    261.000000   261.000000    261
# unique          NaN          NaN      3
# ...

# %%
df.describe()
# Out:
#               mpg   cylinders          hp   time-to-60         year
# count  261.000000  261.000000  261.000000   261.000000   261.000000
# mean    23.144828    5.590038  106.360153    15.547893  1976.819923
# std      7.823570    1.733310   40.499959     2.910625     3.637696
# min     10.000000    3.000000   46.000000     8.000000  1971.000000
# 25%     16.900000    4.000000   75.000000    14.000000  1974.000000
# 50%     22.000000    6.000000   95.000000    16.000000  1977.000000
# 75%     28.800000    8.000000  138.000000    17.000000  1980.000000
# max     46.600000    8.000000  230.000000    25.000000  1983.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
# mpg             261 non-null float64
#  cylinders      261 non-null int64
#  cubicinches    261 non-null object
#  hp             261 non-null int64
#  weightlbs      261 non-null object
#  time-to-60     261 non-null int64
#  year           261 non-null int64
#  brand          261 non-null object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %%
df['mpg']=df['mpg']+1

# %%
df
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    15.0           8          350  165       4209           12   1972
# 1    32.9           4           89   71       1925           14   1980
# 2    18.0           8          302  140       3449           11   1971
# 3    16.0           8          400  150       3761           10   1971
# 4    31.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  18.0           8          305  130       3840           15   1980
# 257  37.1           4           91   60       1800           16   1979
# 258  23.0           6          232  112       2835           15   1983
# 259  19.0           6          232  100       3288           16   1972
# 260  23.0           6          250  105       3353           15   1977
#
#         brand
# 0         US.
# 1     Europe.
# 2         US.
# 3         US.
# 4         US.
# ..        ...
# ...

# %%
mean=df['mpg'].mean()
mean
# Out:
# 24.144827586206894

# %%
df.tail(30)
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 231  29.0           4          120   79       2625           19   1983
# 232  24.0           4          140   78       2592           19   1976
# 233  17.0           8          318  150       4498           15   1976
# 234  21.0           4          130  102       3150           16   1977
# 235  45.0           4           97   52       2130           25   1983
# 236  15.0           8          318  150       4096           13   1972
# 237  21.2           6          200   85       2965           16   1979
# 238  40.0           4           86   64       1875           16   1982
# 239  24.0           4          122   86       2220           14   1972
# 240  14.0           8          350  145       4055           12   1977
# 241  19.0           6          225  105       3121           17   1974
# 242  17.0           8          400  180       4220           11   1978
# ...

# %%
df.head(30)
# Out:
#      mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0   15.0           8          350  165       4209           12   1972
# 1   32.9           4           89   71       1925           14   1980
# 2   18.0           8          302  140       3449           11   1971
# 3   16.0           8          400  150       3761           10   1971
# 4   31.5           4           98   63       2051           17   1978
# 5   24.0           8          350  125       3900           17   1980
# 6   14.0           8          351  158       4363           13   1974
# 7   15.0           8          440  215       4312            9   1971
# 8   26.4           5          183   77       3530           20   1980
# 9   38.7           4           89   62       2050           17   1982
# 10  35.0           4          108   70       2245           17   1983
# 11  35.3           4           97   78       2188           16   1981
# ...

# %%
df.replace('Nan',mean,inplace=True)

# %%
df.iloc[180:216,:]
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 180  20.8           6      24.1448   85       2990           18   1980
# 181  34.8           4           97   67       2145           18   1981
# 182  18.5           8          305  140       4215           13   1977
# 183  19.0           8          318  150       3436           11   1971
# 184  35.0           4          112   88       2395           18   1983
# 185  21.8           6          200   85       3070           17   1979
# 186  19.0           6          250  105       3459           16   1976
# 187  14.0           8          318  150       3940           13   1977
# 188  15.0           8          351  153       4129           13   1973
# 189  14.0           8          440  215       4735           11   1974
# 190  26.8           4          156   92       2620           14   1982
# 191  29.4           4          151   90       2670           16   1980
# ...

# %% [markdown]
# # Normalizing data -A) SIMPLE FEATURE SCALING

# %%
df['mpg1']=df['mpg']/df['mpg'].max()

# %%
df
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    15.0           8          350  165       4209           12   1972
# 1    32.9           4           89   71       1925           14   1980
# 2    18.0           8          302  140       3449           11   1971
# 3    16.0           8          400  150       3761           10   1971
# 4    31.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  18.0           8          305  130       3840           15   1980
# 257  37.1           4           91   60       1800           16   1979
# 258  23.0           6          232  112       2835           15   1983
# 259  19.0           6          232  100       3288           16   1972
# 260  23.0           6          250  105       3353           15   1977
#
#         brand      mpg1
# 0         US.  0.315126
# 1     Europe.  0.691176
# 2         US.  0.378151
# ...

# %% [markdown]
# # B) MIN-MAX

# %%
df
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    15.0           8          350  165       4209           12   1972
# 1    32.9           4           89   71       1925           14   1980
# 2    18.0           8          302  140       3449           11   1971
# 3    16.0           8          400  150       3761           10   1971
# 4    31.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  18.0           8          305  130       3840           15   1980
# 257  37.1           4           91   60       1800           16   1979
# 258  23.0           6          232  112       2835           15   1983
# 259  19.0           6          232  100       3288           16   1972
# 260  23.0           6          250  105       3353           15   1977
#
#         brand      mpg1
# 0         US.  0.315126
# 1     Europe.  0.691176
# 2         US.  0.378151
# ...

# %%
df[' hp']
# Out:
# 0      165
# 1       71
# 2      140
# 3      150
# 4       63
#       ...
# 256    130
# 257     60
# 258    112
# 259    100
# 260    105
# Name:  hp, Length: 261, dtype: int64

# %% [markdown]
# # BINNING

# %%
bins=np.linspace(min(df['mpg']),max(df['mpg']),4)
group_names=["Low","medium","High"]
bins
# Out:
# array([11. , 23.2, 35.4, 47.6])

# %%
df["mpg-bin"]=pd.cut(df["mpg"],bins,labels=group_names,include_lowest=True)

# %%
df
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    15.0           8          350  165       4209           12   1972
# 1    32.9           4           89   71       1925           14   1980
# 2    18.0           8          302  140       3449           11   1971
# 3    16.0           8          400  150       3761           10   1971
# 4    31.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  18.0           8          305  130       3840           15   1980
# 257  37.1           4           91   60       1800           16   1979
# 258  23.0           6          232  112       2835           15   1983
# 259  19.0           6          232  100       3288           16   1972
# 260  23.0           6          250  105       3353           15   1977
#
#         brand      mpg1 mpg-bin
# 0         US.  0.315126     Low
# 1     Europe.  0.691176  medium
# ...

# %%
df.hist(bins=bins)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C08344B648>,
# ...
#       dtype=object)

# %%
df
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    15.0           8          350  165       4209           12   1972
# 1    32.9           4           89   71       1925           14   1980
# 2    18.0           8          302  140       3449           11   1971
# 3    16.0           8          400  150       3761           10   1971
# 4    31.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  18.0           8          305  130       3840           15   1980
# 257  37.1           4           91   60       1800           16   1979
# 258  23.0           6          232  112       2835           15   1983
# 259  19.0           6          232  100       3288           16   1972
# 260  23.0           6          250  105       3353           15   1977
#
#         brand      mpg1 mpg-bin
# 0         US.  0.315126     Low
# 1     Europe.  0.691176  medium
# ...

# %%
pd.get_dummies(df[' brand'])
# Out:
#       Europe.   Japan.   US.
# 0           0        0     1
# 1           1        0     0
# 2           0        0     1
# 3           0        0     1
# 4           0        0     1
# ..        ...      ...   ...
# 256         0        0     1
# 257         0        1     0
# 258         0        0     1
# 259         0        0     1
# 260         0        0     1
#
# [261 rows x 3 columns]

# %%
df
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    15.0           8          350  165       4209           12   1972
# 1    32.9           4           89   71       1925           14   1980
# 2    18.0           8          302  140       3449           11   1971
# 3    16.0           8          400  150       3761           10   1971
# 4    31.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  18.0           8          305  130       3840           15   1980
# 257  37.1           4           91   60       1800           16   1979
# 258  23.0           6          232  112       2835           15   1983
# 259  19.0           6          232  100       3288           16   1972
# 260  23.0           6          250  105       3353           15   1977
#
#         brand      mpg1 mpg-bin
# 0         US.  0.315126     Low
# 1     Europe.  0.691176  medium
# ...

# %%
df.describe()
# Out:
#               mpg   cylinders          hp   time-to-60         year  \
# count  261.000000  261.000000  261.000000   261.000000   261.000000
# mean    24.144828    5.590038  106.360153    15.547893  1976.819923
# std      7.823570    1.733310   40.499959     2.910625     3.637696
# min     11.000000    3.000000   46.000000     8.000000  1971.000000
# 25%     17.900000    4.000000   75.000000    14.000000  1974.000000
# 50%     23.000000    6.000000   95.000000    16.000000  1977.000000
# 75%     29.800000    8.000000  138.000000    17.000000  1980.000000
# max     47.600000    8.000000  230.000000    25.000000  1983.000000
#
#              mpg1
# count  261.000000
# mean     0.507244
# std      0.164361
# min      0.231092
# 25%      0.376050
# 50%      0.483193
# 75%      0.626050
# max      1.000000

# %%
plt.hist(df['mpg'],bins=10)
# Out:
# (array([20., 51., 47., 40., 36., 26., 22., 12.,  2.,  5.]),
#  array([11.  , 14.66, 18.32, 21.98, 25.64, 29.3 , 32.96, 36.62, 40.28,
#         43.94, 47.6 ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(x='mpg',data=df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c0856ab308>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c084d06308>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c0856a1788>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c08a69f7c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c08a6cb248>],
#  'means': []}

# %%
plt.scatter(df['mpg'],df[' cylinders'])
plt.xlabel("MPG")
plt.ylabel("CYLINDERS")
plt.title("CARS")
# Out:
# Text(0.5, 1.0, 'CARS')

# %%
data_test=df[['mpg',' cylinders',' hp']]
df_grp=data_test.groupby(['mpg',' cylinders'],as_index=False).mean()
df_grp
# Out:
#       mpg   cylinders          hp
# 0    11.0           8  215.000000
# 1    12.0           8  165.000000
# 2    13.0           8  192.500000
# 3    14.0           8  160.153846
# 4    15.0           8  169.562500
# ..    ...         ...         ...
# 116  44.1           4   48.000000
# 117  44.4           4   48.000000
# 118  45.0           4   52.000000
# 119  45.3           4   48.000000
# 120  47.6           4   65.000000
#
# [121 rows x 3 columns]

# %%
df_pivot=df_grp.pivot(index='mpg',columns=' cylinders')
df_pivot
# Out:
#             hp
#  cylinders   3     4   5   6           8
# mpg
# 11.0       NaN   NaN NaN NaN  215.000000
# 12.0       NaN   NaN NaN NaN  165.000000
# 13.0       NaN   NaN NaN NaN  192.500000
# 14.0       NaN   NaN NaN NaN  160.153846
# 15.0       NaN   NaN NaN NaN  169.562500
# ...         ..   ...  ..  ..         ...
# 44.1       NaN  48.0 NaN NaN         NaN
# 44.4       NaN  48.0 NaN NaN         NaN
# 45.0       NaN  52.0 NaN NaN         NaN
# 45.3       NaN  48.0 NaN NaN         NaN
# 47.6       NaN  65.0 NaN NaN         NaN
#
# [103 rows x 5 columns]

# %%
plt.pcolor(df_pivot,cmap='RdBu')
plt.colorbar()
plt.show()

# %%
sns.regplot(x='mpg',y=' hp',data=df)
plt.ylim(0,)
# Out:
# (0, 242.05037144851954)

# %%
P_coeff,P_value=stats.pearsonr(df[' hp'],df[' time-to-60'])

# %%
P_coeff
# Out:
# -0.7448731079100701

# %%
P_value
# Out:
# 2.0175068992303555e-47
